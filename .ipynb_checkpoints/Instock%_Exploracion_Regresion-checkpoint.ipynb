# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#date libraries
from dateutil import parser
from datetime import datetime, timedelta, date
import holidays
from unipath import Path

#prophet library
from prophet import Prophet
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric
from prophet.diagnostics import cross_validation


from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split
import math
import sklearn.metrics as metrics

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import math
import sklearn.metrics as metrics

# Import statsmodel
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import adfuller

# %%
def mape(actual, pred):
    '''
    Mean Absolute Percentage Error (MAPE) Function

    input: list/series for actual values and predicted values
    output: mape value
    '''
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
def RMSE(predicted, actual):
    mse = (predicted - actual)**2
    rmse = np.sqrt(mse.sum()/mse.count())
    return rmse

# %%
rutabase = Path('/Users/ronaldverdugol/Desktop/Magister/6to/')

# %%
df = pd.concat(
    map(pd.read_csv, [rutabase +'1.csv', rutabase +'2.csv', rutabase +'3.csv']), ignore_index=True)
df.shape
# Out:
# (90166, 34)

# %%
df.isnull().sum()
# Out:
# FECHA_VENTA               0
# FECHACREACION             0
# DESCRIPCION               0
# CATEG_ID                  0
# item_nbr                  0
# item_desc_1               0
# UNIDADES_VEND             0
# MONTO_VENTA               0
# TOTAL                  4017
# INSTOCK                4017
# QTY_ITEM_SUBCAT           0
# MAXSHELF                228
# CAPACIDAD_ESTANTE       228
# EXISTENCIA               20
# QUIEBRE_STOCK             0
# BIN_QTY                   0
# REPONER_QUIEBRE           0
# LLENAR_GONDOLA            0
# PISOVENTA                20
# BACKROOM                 20
# BIN_INCONSISTENCIAS       0
# COM_BINS                  0
# WHPK_QTY                228
# QUIEBRE_COMP           5881
# SALES_L3W                18
# venta_quiebres            3
# venta_llenado             0
# venta_oostock             0
# QUIEBRES_OPERACION        0
# QUIEBRES_SUPPLY           0
# QUIEBRES_COMERCIAL        0
# QUIEBRES_OTROS            0
# NUMERADOR_NSG             0
# DENOMINADOR_NSG        2181
# dtype: int64

# %%
df = df.drop(['QTY_ITEM_SUBCAT', 'TOTAL', 'QUIEBRE_COMP'], axis =1)

# %%
#df =  df[df.item_nbr.isin([581716, 657947, 254100])]
#agg_item_df.head(10)

# %%
#agg_item_df.shape

# %%
#df = agg_item_df

# %%
na_ratio = ((df.isnull().sum() / len(df))*100).sort_values(ascending = False)
print(na_ratio)
# Out:
# INSTOCK                4.455116
# DENOMINADOR_NSG        2.418872
# WHPK_QTY               0.252867
# CAPACIDAD_ESTANTE      0.252867
# MAXSHELF               0.252867
# EXISTENCIA             0.022181
# PISOVENTA              0.022181
# BACKROOM               0.022181
# SALES_L3W              0.019963
# venta_quiebres         0.003327
# QUIEBRES_SUPPLY        0.000000
# QUIEBRES_OPERACION     0.000000
# venta_oostock          0.000000
# QUIEBRES_COMERCIAL     0.000000
# COM_BINS               0.000000
# QUIEBRES_OTROS         0.000000
# venta_llenado          0.000000
# NUMERADOR_NSG          0.000000
# FECHA_VENTA            0.000000
# BIN_INCONSISTENCIAS    0.000000
# FECHACREACION          0.000000
# REPONER_QUIEBRE        0.000000
# BIN_QTY                0.000000
# QUIEBRE_STOCK          0.000000
# MONTO_VENTA            0.000000
# UNIDADES_VEND          0.000000
# item_desc_1            0.000000
# item_nbr               0.000000
# CATEG_ID               0.000000
# DESCRIPCION            0.000000
# LLENAR_GONDOLA         0.000000
# dtype: float64

# %%
# Crear un DataFrame de ejemplo con valores nulos

# Calcular porcentajes de valores nulos por columna
porcentajes_nulos = df.isnull().mean() * 100
porcentajes_nulos = porcentajes_nulos.sort_values(ascending = True)
# Crear el gráfico de barras horizontales
plt.figure(figsize=(10, 6))
sns.barplot(x=porcentajes_nulos, y=porcentajes_nulos.index, color='skyblue')

# Añadir etiquetas y título
plt.xlabel('% Valores Nulos')
plt.ylabel('Columnas')
plt.title('Porcentaje de Valores Nulos por Columna')

# Mostrar el gráfico
plt.show()

# %%
df.shape
# Out:
# (90166, 31)

# %%
df = df.dropna(how='all', axis = 1)

# %%
df.dtypes
# Out:
# FECHA_VENTA             object
# FECHACREACION           object
# DESCRIPCION             object
# CATEG_ID                object
# item_nbr                 int64
# item_desc_1             object
# UNIDADES_VEND            int64
# MONTO_VENTA              int64
# INSTOCK                float64
# MAXSHELF               float64
# CAPACIDAD_ESTANTE      float64
# EXISTENCIA             float64
# QUIEBRE_STOCK            int64
# BIN_QTY                  int64
# REPONER_QUIEBRE        float64
# LLENAR_GONDOLA         float64
# PISOVENTA              float64
# BACKROOM               float64
# BIN_INCONSISTENCIAS      int64
# COM_BINS                 int64
# WHPK_QTY               float64
# SALES_L3W              float64
# venta_quiebres         float64
# venta_llenado            int64
# venta_oostock            int64
# QUIEBRES_OPERACION       int64
# QUIEBRES_SUPPLY          int64
# QUIEBRES_COMERCIAL       int64
# QUIEBRES_OTROS           int64
# NUMERADOR_NSG            int64
# DENOMINADOR_NSG        float64
# dtype: object

# %%
df.sort_values(by=['FECHA_VENTA', 'item_nbr'], inplace=True)

# Llenar los valores nulos en la columna Instock con el valor del día anterior para ese producto
df.fillna(method='ffill', inplace=True)

# Manejar los casos donde no hay valor anterior disponible
# Suponiendo que si no hay un valor anterior, se debe establecer en False
df.fillna(False, inplace=True)

# %%
df['INSTOCK'].describe()
# Out:
# count    90166.000000
# mean         0.985549
# std          0.119342
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: INSTOCK, dtype: float64

# %%
df.sort_values(by=['FECHA_VENTA', 'item_nbr'], inplace=True)

# Llenar los valores nulos en la columna Instock con el valor del día anterior para ese producto
df['INSTOCK'].fillna(method='ffill', inplace=True)

# Manejar los casos donde no hay valor anterior disponible
# Suponiendo que si no hay un valor anterior, se debe establecer en False
df['INSTOCK'].fillna(False, inplace=True)

# %%
df['DENOMINADOR_NSG'].describe()
# Out:
# count    90166.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: DENOMINADOR_NSG, dtype: float64

# %%
df.sort_values(by=['FECHA_VENTA', 'item_nbr'], inplace=True)

# Llenar los valores nulos en la columna Instock con el valor del día anterior para ese producto
df['DENOMINADOR_NSG'].fillna(method='ffill', inplace=True)

# Manejar los casos donde no hay valor anterior disponible
# Suponiendo que si no hay un valor anterior, se debe establecer en False
df['DENOMINADOR_NSG'].fillna(False, inplace=True)

# %%
df['DENOMINADOR_NSG'].describe()
# Out:
# count    90166.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: DENOMINADOR_NSG, dtype: float64

# %%
df.rename(columns = {'FECHA_VENTA':'DATE'}, inplace = True)

# Cambiamos el formado de la columna 'date'
df.DATE= pd.DatetimeIndex(df.DATE)
df['DATE'].dtype
# es equivalente a datetime64
# Out:
# dtype('<M8[ns]')

# %%
# Crear un DataFrame de ejemplo con valores nulos

# Calcular porcentajes de valores nulos por columna
porcentajes_nulos = df.isnull().mean() * 100
porcentajes_nulos = porcentajes_nulos.sort_values(ascending = True)
# Crear el gráfico de barras horizontales
plt.figure(figsize=(10, 6))
sns.barplot(x=porcentajes_nulos, y=porcentajes_nulos.index, color='skyblue')

# Añadir etiquetas y título
plt.xlabel('% Valores Nulos')
plt.ylabel('Columnas')
plt.title('Porcentaje de Valores Nulos por Columna')

# Mostrar el gráfico
plt.show()

# %%
df.head()
# Out:
#          DATE FECHACREACION                         DESCRIPCION CATEG_ID  \
# 17 2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 22 2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 31 2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 60 2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 49 2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
#
#     item_nbr           item_desc_1  UNIDADES_VEND  MONTO_VENTA  INSTOCK  \
# 17    240159     QUESO RALLADO 80G             43        47122      1.0
# 22    254100  QUESO GOUDA LAMINADO             58       173622      1.0
# 31    254112  QUESO GOUDA LAMINADO              5         8723      1.0
# 60    254124  QUESO GOUDA LAMINADO              9         8890      1.0
# 49    263719         QUESO RALLADO             74        41780      1.0
#
#     MAXSHELF  ...  SALES_L3W  venta_quiebres  venta_llenado  venta_oostock  \
# 17       8.0  ...   668087.0             0.0              0              0
# 22      81.0  ...  3481916.0             0.0              0              0
# 31      72.0  ...   191424.0             0.0              0              0
# 60     112.0  ...   143659.0             0.0              0              0
# 49    1440.0  ...   584836.0             0.0              0              0
#
#     QUIEBRES_OPERACION  QUIEBRES_SUPPLY  QUIEBRES_COMERCIAL  QUIEBRES_OTROS  \
# 17                   0                0                   1               0
# 22                   1                0                   0               0
# 31                   0                0                   0               0
# 60                   0                0                   0               0
# 49                   0                0                   0               0
#
#     NUMERADOR_NSG  DENOMINADOR_NSG
# 17              1              1.0
# 22              1              1.0
# 31              0              1.0
# 60              0              1.0
# 49              0              1.0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (90166, 31)

# %%
# Podemos reindexar nuestro dataframe
#df = df.sort_values(by = "DATE")
#df.index = pd.PeriodIndex(df.DATE, freq='D')
#df.head()

# %%
#df = df.dropna()

# %%
# Calcular la correlación de las variables dependientes con respecto a la variable objetivo
correlaciones = df.drop('UNIDADES_VEND', axis=1)
# Ordenar las correlaciones de mayor a menor
correlaciones = correlaciones.corrwith(df['UNIDADES_VEND'], numeric_only=True)

correlaciones = correlaciones.sort_values(ascending=False)

# Crear el gráfico de barras horizontales
plt.figure(figsize=(10, 6))
sns.barplot(x=correlaciones, y=correlaciones.index, color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Correlación con Variable Objetivo')
plt.ylabel('Variables Dependientes')
plt.title('Correlación de Variables Dependientes con UNIDADES_VEND')

# Mostrar el gráfico
plt.show()

# %%
df_bkp=df

# %%
df
# Out:
#             DATE FECHACREACION                         DESCRIPCION CATEG_ID  \
# 17    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 22    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 31    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 60    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 49    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# ...          ...           ...                                 ...      ...
# 90084 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90090 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90047 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90093 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90022 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
#
#        item_nbr           item_desc_1  UNIDADES_VEND  MONTO_VENTA  INSTOCK  \
# 17       240159     QUESO RALLADO 80G             43        47122      1.0
# 22       254100  QUESO GOUDA LAMINADO             58       173622      1.0
# 31       254112  QUESO GOUDA LAMINADO              5         8723      1.0
# 60       254124  QUESO GOUDA LAMINADO              9         8890      1.0
# 49       263719         QUESO RALLADO             74        41780      1.0
# ...         ...                   ...            ...          ...      ...
# 90084   5028517  TABLA QUESO PARRILLE              1         5958      1.0
# 90090   5029865  QUESO MANTEC OREGANO              2         7378      1.0
# 90047   5029866   QUESO MANTEC MERKEN              1         3689      1.0
# 90093   5035128     QUESO GAUDA TROZO              5         9200      1.0
# 90022   5042804  QUESO TROZO MANTECOS              8        40272      1.0
#
#        MAXSHELF  ...  SALES_L3W  venta_quiebres  venta_llenado  venta_oostock  \
# 17          8.0  ...   668087.0             0.0              0              0
# 22         81.0  ...  3481916.0             0.0              0              0
# 31         72.0  ...   191424.0             0.0              0              0
# 60        112.0  ...   143659.0             0.0              0              0
# 49       1440.0  ...   584836.0             0.0              0              0
# ...         ...  ...        ...             ...            ...            ...
# 90084      48.0  ...   165748.0             0.0              0              0
# 90090      12.0  ...   101628.0             0.0              0              0
# 90047      12.0  ...    33319.0             0.0              0              0
# 90093       0.0  ...    25760.0             0.0              0              0
# 90022      24.0  ...   452054.0             0.0              0              0
#
#        QUIEBRES_OPERACION  QUIEBRES_SUPPLY  QUIEBRES_COMERCIAL  \
# 17                      0                0                   1
# 22                      1                0                   0
# 31                      0                0                   0
# 60                      0                0                   0
# 49                      0                0                   0
# ...                   ...              ...                 ...
# 90084                   0                0                   0
# 90090                   0                0                   0
# 90047                   0                0                   0
# 90093                   0                0                   0
# 90022                   0                0                   0
#
#        QUIEBRES_OTROS  NUMERADOR_NSG  DENOMINADOR_NSG
# 17                  0              1              1.0
# 22                  0              1              1.0
# 31                  0              0              1.0
# 60                  0              0              1.0
# 49                  0              0              1.0
# ...               ...            ...              ...
# 90084               0              0              1.0
# 90090               0              0              1.0
# 90047               0              0              1.0
# 90093               0              0              1.0
# 90022               0              0              1.0
#
# [90166 rows x 31 columns]

# %%
df_heat =df

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_heat.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df_heat
# Out:
#             DATE FECHACREACION                         DESCRIPCION CATEG_ID  \
# 17    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 22    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 31    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 60    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 49    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# ...          ...           ...                                 ...      ...
# 90084 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90090 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90047 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90093 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90022 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
#
#        item_nbr           item_desc_1  UNIDADES_VEND  MONTO_VENTA  INSTOCK  \
# 17       240159     QUESO RALLADO 80G             43        47122      1.0
# 22       254100  QUESO GOUDA LAMINADO             58       173622      1.0
# 31       254112  QUESO GOUDA LAMINADO              5         8723      1.0
# 60       254124  QUESO GOUDA LAMINADO              9         8890      1.0
# 49       263719         QUESO RALLADO             74        41780      1.0
# ...         ...                   ...            ...          ...      ...
# 90084   5028517  TABLA QUESO PARRILLE              1         5958      1.0
# 90090   5029865  QUESO MANTEC OREGANO              2         7378      1.0
# 90047   5029866   QUESO MANTEC MERKEN              1         3689      1.0
# 90093   5035128     QUESO GAUDA TROZO              5         9200      1.0
# 90022   5042804  QUESO TROZO MANTECOS              8        40272      1.0
#
#        MAXSHELF  ...  SALES_L3W  venta_quiebres  venta_llenado  venta_oostock  \
# 17          8.0  ...   668087.0             0.0              0              0
# 22         81.0  ...  3481916.0             0.0              0              0
# 31         72.0  ...   191424.0             0.0              0              0
# 60        112.0  ...   143659.0             0.0              0              0
# 49       1440.0  ...   584836.0             0.0              0              0
# ...         ...  ...        ...             ...            ...            ...
# 90084      48.0  ...   165748.0             0.0              0              0
# 90090      12.0  ...   101628.0             0.0              0              0
# 90047      12.0  ...    33319.0             0.0              0              0
# 90093       0.0  ...    25760.0             0.0              0              0
# 90022      24.0  ...   452054.0             0.0              0              0
#
#        QUIEBRES_OPERACION  QUIEBRES_SUPPLY  QUIEBRES_COMERCIAL  \
# 17                      0                0                   1
# 22                      1                0                   0
# 31                      0                0                   0
# 60                      0                0                   0
# 49                      0                0                   0
# ...                   ...              ...                 ...
# 90084                   0                0                   0
# 90090                   0                0                   0
# 90047                   0                0                   0
# 90093                   0                0                   0
# 90022                   0                0                   0
#
#        QUIEBRES_OTROS  NUMERADOR_NSG  DENOMINADOR_NSG
# 17                  0              1              1.0
# 22                  0              1              1.0
# 31                  0              0              1.0
# 60                  0              0              1.0
# 49                  0              0              1.0
# ...               ...            ...              ...
# 90084               0              0              1.0
# 90090               0              0              1.0
# 90047               0              0              1.0
# 90093               0              0              1.0
# 90022               0              0              1.0
#
# [90166 rows x 31 columns]

# %%
df_heat.hist(figsize=(60,60))
plt.tight_layout()
plt.show()

# %%
x = df_heat['UNIDADES_VEND']
sns.histplot(x = x,  kde=True, stat="density", bins=500, element = "poly" )
# Out:
# <Axes: xlabel='UNIDADES_VEND', ylabel='Density'>

# %%
x = df_heat['UNIDADES_VEND']

# Crear el gráfico de distribución con seaborn
sns.histplot(x=x, stat="density", element="poly", bins=600)

# Configurar el eje x en escala logarítmica
plt.xscale('log')

# Cambiar el eje y a porcentaje
plt.ylabel('Porcentaje')
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

# Mostrar el gráfico
plt.show()
# Out:
# /var/folders/l_/_pmt0znn2bsg_f3mnw2xb1xh0000gn/T/ipykernel_74530/3924940944.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

# %%
item_df=  df[df.item_nbr.isin([581716, 254100, 657947])]

# %%
df['UNIDADES_VEND'].describe()
# Out:
# count    90166.000000
# mean        11.925759
# std         24.104604
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%         10.000000
# max        596.000000
# Name: UNIDADES_VEND, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt


# Crear el boxplot
plt.figure(figsize=(5,5))
plt.boxplot(df['UNIDADES_VEND'])

# Configurar la escala del eje y en logarítmica
plt.yscale('log')

# Etiquetar el eje y como "Unidades Vendidas"
plt.ylabel('Unidades Vendidas')

# Calcular el promedio y agregar su valor numérico y marcador en el boxplot
promedio = df['UNIDADES_VEND'].mean()
plt.text(1.1, promedio, f'Promedio: {promedio:.2f}', color='red', fontsize=10, verticalalignment='bottom')
plt.plot(1, promedio, 'ro')  # Añadir marcador en el boxplot

# Mostrar el boxplot
plt.show()

# %%
df = df_bkp

# %%
df.shape
# Out:
# (90166, 31)

# %%
agg_item_df = df.groupby(['DATE', 'item_nbr', 'item_desc_1']).agg({'UNIDADES_VEND':'sum'}).reset_index().sort_values(['UNIDADES_VEND'], ascending = False)

# %%
agg_item_df.head()
# Out:
#             DATE  item_nbr           item_desc_1  UNIDADES_VEND
# 56670 2023-05-08    276563  QUESO PARMESANO RALL            596
# 31920 2022-11-14    581716  Q. MANT R BUENO L500            591
# 74496 2023-09-09    276563  QUESO PARMESANO RALL            577
# 31477 2022-11-11    581716  Q. MANT R BUENO L500            509
# 74654 2023-09-10    276563  QUESO PARMESANO RALL            451

# %% [markdown]
# ## 3 Productos

# %%
agg_item_df_3p =  agg_item_df[agg_item_df.item_nbr.isin([581716, 657947, 254100])]

# %%
agg_item_df_3p.UNIDADES_VEND.describe()
# Out:
# count    1858.000000
# mean       93.354144
# std        52.157197
# min         1.000000
# 25%        56.000000
# 50%        84.000000
# 75%       120.000000
# max       591.000000
# Name: UNIDADES_VEND, dtype: float64

# %%
x = agg_item_df_3p['UNIDADES_VEND']

# Crear el gráfico de distribución con seaborn
sns.histplot(x=x, stat="density", element="poly")

# Configurar el eje x en escala logarítmica
#plt.xscale('log')

# Cambiar el eje y a porcentaje
plt.ylabel('Densidad')
#plt.gca().set_yticklabels(['{:.0f}%'.format(x*10000) for x in plt.gca().get_yticks()])

# Mostrar el gráfico
plt.show()

# %%
# Crear el boxplot
plt.figure(figsize=(5,5))
plt.boxplot(agg_item_df_3p['UNIDADES_VEND'])

# Configurar la escala del eje y en logarítmica
plt.yscale('log')

# Etiquetar el eje y como "Unidades Vendidas"
plt.ylabel('Unidades Vendidas')

# Calcular el promedio y agregar su valor numérico y marcador en el boxplot
promedio = agg_item_df_3p['UNIDADES_VEND'].mean()
plt.text(1.1, promedio, f'Promedio: {promedio:.2f}', color='red', fontsize=10, verticalalignment='bottom')
plt.plot(1, promedio, 'ro')  # Añadir marcador en el boxplot

# Mostrar el boxplot
plt.show()

# %%
df_heat3p =  df[df.item_nbr.isin([581716, 657947, 254100])]
plt.figure(figsize=(8,6))
sns.heatmap(df_heat3p.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ## Eliminación variables correlacionadas y sin gestión

# %%
y = df['UNIDADES_VEND']
X = df.drop(['UNIDADES_VEND','DATE','FECHACREACION', 'DESCRIPCION', 'CATEG_ID', 'item_desc_1', 'item_nbr', 'MONTO_VENTA'], axis =1)

# %%
df
# Out:
#             DATE FECHACREACION                         DESCRIPCION CATEG_ID  \
# 17    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 22    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 31    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 60    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 49    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# ...          ...           ...                                 ...      ...
# 90084 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90090 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90047 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90093 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90022 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
#
#        item_nbr           item_desc_1  UNIDADES_VEND  MONTO_VENTA  INSTOCK  \
# 17       240159     QUESO RALLADO 80G             43        47122      1.0
# 22       254100  QUESO GOUDA LAMINADO             58       173622      1.0
# 31       254112  QUESO GOUDA LAMINADO              5         8723      1.0
# 60       254124  QUESO GOUDA LAMINADO              9         8890      1.0
# 49       263719         QUESO RALLADO             74        41780      1.0
# ...         ...                   ...            ...          ...      ...
# 90084   5028517  TABLA QUESO PARRILLE              1         5958      1.0
# 90090   5029865  QUESO MANTEC OREGANO              2         7378      1.0
# 90047   5029866   QUESO MANTEC MERKEN              1         3689      1.0
# 90093   5035128     QUESO GAUDA TROZO              5         9200      1.0
# 90022   5042804  QUESO TROZO MANTECOS              8        40272      1.0
#
#        MAXSHELF  ...  SALES_L3W  venta_quiebres  venta_llenado  venta_oostock  \
# 17          8.0  ...   668087.0             0.0              0              0
# 22         81.0  ...  3481916.0             0.0              0              0
# 31         72.0  ...   191424.0             0.0              0              0
# 60        112.0  ...   143659.0             0.0              0              0
# 49       1440.0  ...   584836.0             0.0              0              0
# ...         ...  ...        ...             ...            ...            ...
# 90084      48.0  ...   165748.0             0.0              0              0
# 90090      12.0  ...   101628.0             0.0              0              0
# 90047      12.0  ...    33319.0             0.0              0              0
# 90093       0.0  ...    25760.0             0.0              0              0
# 90022      24.0  ...   452054.0             0.0              0              0
#
#        QUIEBRES_OPERACION  QUIEBRES_SUPPLY  QUIEBRES_COMERCIAL  \
# 17                      0                0                   1
# 22                      1                0                   0
# 31                      0                0                   0
# 60                      0                0                   0
# 49                      0                0                   0
# ...                   ...              ...                 ...
# 90084                   0                0                   0
# 90090                   0                0                   0
# 90047                   0                0                   0
# 90093                   0                0                   0
# 90022                   0                0                   0
#
#        QUIEBRES_OTROS  NUMERADOR_NSG  DENOMINADOR_NSG
# 17                  0              1              1.0
# 22                  0              1              1.0
# 31                  0              0              1.0
# 60                  0              0              1.0
# 49                  0              0              1.0
# ...               ...            ...              ...
# 90084               0              0              1.0
# 90090               0              0              1.0
# 90047               0              0              1.0
# 90093               0              0              1.0
# 90022               0              0              1.0
#
# [90166 rows x 31 columns]

# %%
X = X.values
y = y.values

# %%
df['UNIDADES_VEND']
# Out:
# 17       43
# 22       58
# 31        5
# 60        9
# 49       74
#          ..
# 90084     1
# 90090     2
# 90047     1
# 90093     5
# 90022     8
# Name: UNIDADES_VEND, Length: 90166, dtype: int64

# %% [markdown]
# # División Entrenamiento - Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=10, shuffle = "True")

# %%
X_train.shape
# Out:
# (63116, 23)

# %%
print('Shape X: ', X.shape)
print('Shape y: ', y.shape)
print('Shape X_test: ', X_test.shape)
print('Shape y_test: ', y_test.shape)
# Out:
# Shape X:  (90166, 23)
# Shape y:  (90166,)
# Shape X_test:  (27050, 23)
# Shape y_test:  (27050,)

# %%
lin_reg = LinearRegression() #Creamos un modelo
lin_reg.fit(X_train, y_train)  #Entrenamos el modelo
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)
y_pred.shape
# Out:
# (27050,)

# %%
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
print('Estadístico R_2: %.2f' % r2_score(y_test, y_pred))
#print('Estadístico MAE: %.2f' % mean_absolute_error(y_test, y_pred))
# Out:
# Error cuadrático medio: 222.49
# Estadístico R_2: 0.64

# %%
from sklearn.preprocessing import PolynomialFeatures
transformer = PolynomialFeatures(degree=2)
transformer.fit(X)
X_ = transformer.transform(X)
print(X)
print(X_)
# Out:
# [[ 1.  8.  0. ...  0.  1.  1.]
#  [ 1. 81. 81. ...  0.  1.  1.]
#  [ 1. 72.  0. ...  0.  0.  1.]
#  ...
#  [ 1. 12. 12. ...  0.  0.  1.]
#  [ 1.  0.  0. ...  0.  0.  1.]
#  [ 1. 24. 24. ...  0.  0.  1.]]
# [[ 1.  1.  8. ...  1.  1.  1.]
#  [ 1.  1. 81. ...  1.  1.  1.]
#  [ 1.  1. 72. ...  0.  0.  1.]
#  ...
#  [ 1.  1. 12. ...  0.  0.  1.]
#  [ 1.  1.  0. ...  0.  0.  1.]
#  [ 1.  1. 24. ...  0.  0.  1.]]

# %%
#definimos un metodo para la regresion polinomial
def PolynomialRegression(degree=2, **kwargs): #Por defecto tendrá grado 0
    return make_pipeline(sklearn.preprocessing.PolynomialFeatures(degree),
                         LinearRegression(**kwargs))

# %%
model = PolynomialRegression(2) #Creamos un modelo con la función que definimos
model.fit(X_train, y_train) #Le pasamos los puntos para entrenar
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = model.predict(X_test) #Predecimos

# %%
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
print('Estadístico R_2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Error cuadrático medio: 206.46
# Estadístico R_2: 0.67

# %%
#En este caso para poder ocupar validación cruzada con regresión polinomial tenemos que definirla como un modelo
from sklearn.base import BaseEstimator
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline


class PolynomialRegression(BaseEstimator): #Necesario crear una clase utilizando de base el BaseEstimator para ocupar cv
  def __init__(self, grado = None):
    self.grado = grado

  def fit(self, X, Y, grado = None):
    self.model = make_pipeline(sklearn.preprocessing.PolynomialFeatures(self.grado),
                         LinearRegression())
    self.model.fit(X,Y)

  def predict(self, X):
    return self.model.predict(X)

  @property
  def coef_(self):
    return self.model.named_steps['linearregression'].coef_

  @property
  def intercept_(self):
    return self.model.named_steps['linearregression'].intercept_

# %%
# ¿Que parametros vamos a ajustar? El grado del polinomio solamente
# ¿Que valores vamos a probar para el parámetro grado? Para este ejemplo: 4, 7, 10 y 13

#diccionario de parámetros y sus valores
parametros = {
    "grado": [1,2,3]
}

# %%
from sklearn.model_selection import GridSearchCV
#Creamos nuestro modelo
modelo = PolynomialRegression()
#Creamos nuestra instancia de la validacion cruzada (es como un modelo)

datos_x = X
datos_y = y
numero_folds = 5

cv_model = GridSearchCV(modelo,
                        parametros,
                        cv=numero_folds, #Aqui se indica el numero de folds
                        scoring='neg_mean_squared_error',
                        verbose=3) #Le pasamos el modelo, los parametros, numero de folds y la métrica


cv_model.fit(datos_x, datos_y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ........................grado=1;, score=-222.812 total time=   0.1s
# [CV 2/5] END ........................grado=1;, score=-192.443 total time=   0.1s
# [CV 3/5] END ........................grado=1;, score=-152.967 total time=   0.1s
# [CV 4/5] END ........................grado=1;, score=-302.784 total time=   0.3s
# [CV 5/5] END ........................grado=1;, score=-234.213 total time=   0.2s
# [CV 1/5] END .....................grado=2;, score=-255829.307 total time=   2.0s
# [CV 2/5] END ........................grado=2;, score=-178.225 total time=   2.0s
# [CV 3/5] END ........................grado=2;, score=-155.140 total time=   2.0s
# [CV 4/5] END ........................grado=2;, score=-883.946 total time=   1.9s
# [CV 5/5] END ........................grado=2;, score=-261.055 total time=   1.9s
# [CV 1/5] END ................grado=3;, score=-71758470730.268 total time=  37.6s
# [CV 2/5] END .......................grado=3;, score=-1150.234 total time=  34.5s
# [CV 3/5] END ........................grado=3;, score=-232.558 total time=  34.2s
# [CV 4/5] END .......................grado=3;, score=-5219.835 total time=  34.8s
# [CV 5/5] END ........................grado=3;, score=-238.573 total time=  46.6s
# GridSearchCV(cv=5, estimator=PolynomialRegression(),
#              param_grid={'grado': [1, 2, 3]}, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
#Le pido que me diga la combinación de parámetros que mejor se ajusta a los datos
cv_model.best_params_
# Out:
# {'grado': 1}

# %%
from sklearn.ensemble import RandomForestRegressor

# create regressor object
model = RandomForestRegressor()
model.fit(X_train, y_train)

# fit the regressor with x and y data
# Out:
# RandomForestRegressor()

# %%
y_test.shape
# Out:
# (27050,)

# %%
y_pred_rf = model.predict(X_test)

# %%
# Show model results of training set

mae = metrics.mean_absolute_error(y_test,y_pred_rf)
mse = metrics.mean_squared_error(y_test,y_pred_rf)
print ("TRAINING SET")
print ("============")
print ("MAE:                ", mae)
print ("RMSE:               ", math.sqrt(mse))
print ("r2:                 ", model.score(X,y))
print ("feature_importances:",model.feature_importances_)
print ("n_outputs:          ",model.n_outputs_)
# Out:
# TRAINING SET
# ============
# MAE:                 4.967856852243053
# RMSE:                12.865051433725215
# r2:                  0.8903344762974239
# feature_importances: [1.34889698e-04 8.26388444e-02 2.02711711e-02 4.32201086e-01
#  3.24248234e-05 1.84060458e-02 9.39213565e-04 1.36426174e-03
#  4.55904570e-02 4.23559971e-02 3.81754892e-04 1.81677370e-03
#  3.00220005e-02 3.14214706e-01 3.41539722e-04 2.74217068e-03
#  3.72561001e-04 2.30854637e-03 4.79064590e-04 9.63707187e-04
#  2.11562773e-06 2.42066811e-03 0.00000000e+00]
# n_outputs:           1

# %%
df
# Out:
#             DATE FECHACREACION                         DESCRIPCION CATEG_ID  \
# 17    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 22    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 31    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 60    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 49    2022-04-06    2022-04-05  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# ...          ...           ...                                 ...      ...
# 90084 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90090 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90047 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90093 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
# 90022 2023-12-31    2023-12-30  QUESOS AUTOSERVICIO - QUESO MADURO  SC18979
#
#        item_nbr           item_desc_1  UNIDADES_VEND  MONTO_VENTA  INSTOCK  \
# 17       240159     QUESO RALLADO 80G             43        47122      1.0
# 22       254100  QUESO GOUDA LAMINADO             58       173622      1.0
# 31       254112  QUESO GOUDA LAMINADO              5         8723      1.0
# 60       254124  QUESO GOUDA LAMINADO              9         8890      1.0
# 49       263719         QUESO RALLADO             74        41780      1.0
# ...         ...                   ...            ...          ...      ...
# 90084   5028517  TABLA QUESO PARRILLE              1         5958      1.0
# 90090   5029865  QUESO MANTEC OREGANO              2         7378      1.0
# 90047   5029866   QUESO MANTEC MERKEN              1         3689      1.0
# 90093   5035128     QUESO GAUDA TROZO              5         9200      1.0
# 90022   5042804  QUESO TROZO MANTECOS              8        40272      1.0
#
#        MAXSHELF  ...  SALES_L3W  venta_quiebres  venta_llenado  venta_oostock  \
# 17          8.0  ...   668087.0             0.0              0              0
# 22         81.0  ...  3481916.0             0.0              0              0
# 31         72.0  ...   191424.0             0.0              0              0
# 60        112.0  ...   143659.0             0.0              0              0
# 49       1440.0  ...   584836.0             0.0              0              0
# ...         ...  ...        ...             ...            ...            ...
# 90084      48.0  ...   165748.0             0.0              0              0
# 90090      12.0  ...   101628.0             0.0              0              0
# 90047      12.0  ...    33319.0             0.0              0              0
# 90093       0.0  ...    25760.0             0.0              0              0
# 90022      24.0  ...   452054.0             0.0              0              0
#
#        QUIEBRES_OPERACION  QUIEBRES_SUPPLY  QUIEBRES_COMERCIAL  \
# 17                      0                0                   1
# 22                      1                0                   0
# 31                      0                0                   0
# 60                      0                0                   0
# 49                      0                0                   0
# ...                   ...              ...                 ...
# 90084                   0                0                   0
# 90090                   0                0                   0
# 90047                   0                0                   0
# 90093                   0                0                   0
# 90022                   0                0                   0
#
#        QUIEBRES_OTROS  NUMERADOR_NSG  DENOMINADOR_NSG
# 17                  0              1              1.0
# 22                  0              1              1.0
# 31                  0              0              1.0
# 60                  0              0              1.0
# 49                  0              0              1.0
# ...               ...            ...              ...
# 90084               0              0              1.0
# 90090               0              0              1.0
# 90047               0              0              1.0
# 90093               0              0              1.0
# 90022               0              0              1.0
#
# [90166 rows x 31 columns]

# %%
importances = model.feature_importances_
nombres_caracteristicas = df.drop(['UNIDADES_VEND', 'DATE','FECHACREACION', 'DESCRIPCION', 'item_nbr', 'CATEG_ID', 'MONTO_VENTA', 'item_desc_1'], axis =1).columns.tolist()
# Crear un gráfico de barras de las importancias de las características con etiquetas en el eje x
plt.figure(figsize=(10, 6))  # Tamaño del gráfico (ajústalo según tus preferencias)
plt.bar(range(len(importances)), importances, tick_label=nombres_caracteristicas)
plt.xlabel('Características')
plt.ylabel('Importancia')
plt.title('Importancia de las Características')

# Rotar las etiquetas del eje x para mayor legibilidad (ajusta el ángulo según tus necesidades)
plt.xticks(rotation=90)

# Mostrar el gráfico de barras
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search
param_grid = {
    'criterion':['squared_error','friedman_mse'],
    'bootstrap': [True],
    'max_depth': [50],
    'min_samples_leaf': [3],
    'min_samples_split': [10],
    'n_estimators': [10, 50, 100]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid,
                          cv = 5, n_jobs = -1, scoring = 'neg_mean_squared_error', verbose=2)

# %%
# Fit the grid search to the data
grid_search.fit(X, y)
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# {'bootstrap': True,
#  'criterion': 'squared_error',
#  'max_depth': 50,
#  'min_samples_leaf': 3,
#  'min_samples_split': 10,
#  'n_estimators': 100}

# %%
grid_search.best_score_
# Out:
# -198.9599592538001

# %%
best_model = grid_search.best_estimator_
y_pred_rf = best_model.predict(X_test)

# %%
# Show model results of training set

mae = metrics.mean_absolute_error(y_test,y_pred_rf)
mse = metrics.mean_squared_error(y_test,y_pred_rf)
print ("TRAINING SET")
print ("============")
print ("MAE:                ", mae)
print ("RMSE:               ", math.sqrt(mse))
print ("r2:                 ", model.score(X,y))
print ("feature_importances:",model.feature_importances_)
print ("n_outputs:          ",model.n_outputs_)
# Out:
# TRAINING SET
# ============
# MAE:                 3.2527173055557843
# RMSE:                8.834798675333378
# r2:                  0.8903344762974239
# feature_importances: [1.34889698e-04 8.26388444e-02 2.02711711e-02 4.32201086e-01
#  3.24248234e-05 1.84060458e-02 9.39213565e-04 1.36426174e-03
#  4.55904570e-02 4.23559971e-02 3.81754892e-04 1.81677370e-03
#  3.00220005e-02 3.14214706e-01 3.41539722e-04 2.74217068e-03
#  3.72561001e-04 2.30854637e-03 4.79064590e-04 9.63707187e-04
#  2.11562773e-06 2.42066811e-03 0.00000000e+00]
# n_outputs:           1
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  42.5s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  40.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  42.1s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  41.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.4min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.4min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.3min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.3min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.4min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  42.6s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  42.9s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   9.0s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.4s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.4s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  41.8s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  56.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   9.0s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.3s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.4s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=10; total time=   8.6s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  41.5s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  52.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  41.8s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=  41.0s
# [CV] END bootstrap=True, criterion=friedman_mse, max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  49.0s
